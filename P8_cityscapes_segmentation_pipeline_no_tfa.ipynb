# %% [markdown]
# <a href="https://colab.research.google.com/github/nicop1709/projet8-cityscapes/blob/main/P8_cityscapes_segmentation_pipeline_no_tfa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projet 8 — Pipeline complet Cityscapes (8 classes) : Entraînement, Évaluation et Prédiction
#
# Version sans `tensorflow-addons` (compat. Colab standard).
#
# - Chargement Cityscapes (chemins Drive)
# - Remap → 8 classes
# - `tf.data` + augmentations
# - Modèles : **U-Net** et **U-Net+MobileNetV2**
# - mIoU (callback maison), export **SavedModel**
# - Artefacts pour API (config, palette, LUT, metrics)
# - Prédiction + visualisation

# %% [markdown]
# ## 0. Environnement & dépendances

# %%
# Pas de tensorflow-addons requis
import os, sys, json, math, time, itertools, random
from pathlib import Path
from pprint import pprint

import numpy as np
import tensorflow as tf
import pandas as pd
print("TensorFlow:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1. Chemins & configuration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH_PROJECT = '/content/drive/MyDrive/AI Engineer/Projets/Projet 8 - Segmentation images voitures autonomes'

FOLDER_TRAINING_IMAGES = PATH_PROJECT + "/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train"
FOLDER_TRAINING_MASK   = PATH_PROJECT + "/P8_Cityscapes_gtFine_trainvaltest/gtFine/train"
FOLDER_VALIDATION_IMAGES = PATH_PROJECT + "/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val"
FOLDER_VALIDATION_MASK   = PATH_PROJECT + "/P8_Cityscapes_gtFine_trainvaltest/gtFine/val"
FOLDER_TEST_IMAGES = PATH_PROJECT + "/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/test"
FOLDER_TEST_MASK   = PATH_PROJECT + "/P8_Cityscapes_gtFine_trainvaltest/gtFine/test"

IMG_HEIGHT, IMG_WIDTH = 512, 1024
N_CLASSES = 8
BATCH_SIZE = 4
EPOCHS = 25
SEED = 42

OUT_DIR = Path(PATH_PROJECT) / "artifacts_training"
OUT_DIR.mkdir(parents=True, exist_ok=True)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("OUT_DIR:", OUT_DIR)
# Out:
# OUT_DIR: /content/drive/MyDrive/AI Engineer/Projets/Projet 8 - Segmentation images voitures autonomes/artifacts_training

# %%
for path in [FOLDER_TRAINING_IMAGES,
             FOLDER_TRAINING_MASK,
             FOLDER_VALIDATION_IMAGES,
             FOLDER_VALIDATION_MASK,
             FOLDER_TEST_IMAGES,
             FOLDER_TEST_MASK
             ]:
  print(os.listdir(path))
# Out:
# ['zurich', 'strasbourg', 'weimar', 'tubingen', 'jena', 'aachen', 'bochum', 'dusseldorf', 'darmstadt', 'cologne', 'hamburg', 'krefeld', 'monchengladbach', 'hanover', 'stuttgart', 'ulm', 'erfurt', 'bremen']
# ['weimar', 'tubingen', 'zurich', 'aachen', 'strasbourg', 'bochum', 'jena', 'dusseldorf', 'ulm', 'darmstadt', 'hamburg', 'cologne', 'monchengladbach', 'stuttgart', 'erfurt', 'hanover', 'krefeld', 'bremen']
# ['munster', 'frankfurt', 'lindau']
# ['lindau', 'munster', 'frankfurt']
# ['bielefeld', 'bonn', 'leverkusen', 'berlin', 'mainz', 'munich']
# ['leverkusen', 'bielefeld', 'bonn', 'berlin', 'mainz', 'munich']

# %%
image_counts = []

# Define the image folders to process
image_folders = {
    "train": FOLDER_TRAINING_IMAGES,
    "val": FOLDER_VALIDATION_IMAGES,
    "test": FOLDER_TEST_IMAGES
}

# Iterate through each dataset split (train, val, test)
for split_name, folder_path in image_folders.items():
    print(f"[INFO]: Processing {split_name} images in {folder_path}")
    # Iterate through each city subfolder in the current split
    for city_folder in os.listdir(folder_path):
        city_folder_full_path = os.path.join(folder_path, city_folder)
        if os.path.isdir(city_folder_full_path):
            # Count the number of image files (assuming .png) in the city folder
            num_images = len([f for f in os.listdir(city_folder_full_path) if f.endswith('.png')])
            image_counts.append({
                "split": split_name,
                "city": city_folder,
                "image_count": num_images
            })

# Create a DataFrame from the collected data
images_per_city_df = pd.DataFrame(image_counts)

print("\nDataFrame of image counts per city and split:")
images_per_city_df
# Out:
# [INFO]: Processing train images in /content/drive/MyDrive/AI Engineer/Projets/Projet 8 - Segmentation images voitures autonomes/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/train
# [INFO]: Processing val images in /content/drive/MyDrive/AI Engineer/Projets/Projet 8 - Segmentation images voitures autonomes/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/val
# [INFO]: Processing test images in /content/drive/MyDrive/AI Engineer/Projets/Projet 8 - Segmentation images voitures autonomes/P8_Cityscapes_leftImg8bit_trainvaltest/leftImg8bit/test
#
# DataFrame of image counts per city and split:
#     split             city  image_count
# 0   train           zurich          122
# 1   train       strasbourg          365
# 2   train           weimar          142
# 3   train         tubingen          144
# 4   train             jena          119
# 5   train           aachen          174
# 6   train           bochum           96
# 7   train       dusseldorf          221
# 8   train        darmstadt           85
# 9   train          cologne          154
# 10  train          hamburg          248
# 11  train          krefeld           99
# 12  train  monchengladbach           94
# 13  train          hanover          196
# 14  train        stuttgart          196
# 15  train              ulm           95
# 16  train           erfurt          109
# 17  train           bremen          316
# 18    val          munster          174
# 19    val        frankfurt          267
# 20    val           lindau           59
# 21   test        bielefeld          181
# 22   test             bonn           46
# 23   test       leverkusen           58
# 24   test           berlin          544
# 25   test            mainz          298
# 26   test           munich          398

# %%
# Nb of images by split
images_per_city_df.groupby(["split"])['image_count'].sum()
# Out:
# split
# test     1525
# train    2975
# val       500
# Name: image_count, dtype: int64

# %%
# Define a dataframe with Pandas
dataset_df = pd.DataFrame()

if os.path.exists(PATH_PROJECT+'/train.csv'):
  dataset_df = pd.read_csv(PATH_PROJECT+"/train.csv",
                         converters={"labels": json.loads, "labels_main": json.loads},index_col="image_id")
  dataset_df.index.name = 'index'
else:
  # Loop over city folder
  for city_folder in os.listdir(FOLDER_TRAINING_MASK):
      print("[INFO]: Processing city folder ", city_folder)

      city_folder_full = os.path.join(FOLDER_TRAINING_MASK, city_folder)

      # Loop in each city folder
      for i, file in enumerate(os.listdir(city_folder_full)):

          # Parse only json file
          if file.endswith("json"):
              print(f"[INFO]: Processing file {i+1} / {len(os.listdir(city_folder_full))}: {file}")
              filename = os.path.join(city_folder_full, file)

              # In each json file, pop labels
              with open(filename) as json_file:
                  data = json.load(json_file)
                  labels = list()
                  labels_main = list()

                  for elt in data["objects"]:
                      for k, v in elt.items():
                          if k == "label":
                              labels.append(v)
                              try:
                                  labels_main.append(name2label[v][3])
                              except:
                                  pass

                  data["labels"] = labels
                  data["labels_count"] = len(labels)

                  data["labels_main"] = labels_main
                  data["labels_main_count"] = len(labels_main)

                  data["city"] = city_folder
                  del data["objects"]

              basename = "_".join(file.split(".")[0].split("_")[:3])

              df_tmp = pd.DataFrame.from_dict(data, orient='index', columns=[basename]).T
              dataset_df = pd.concat([dataset_df, df_tmp])
              (dataset_df
    .assign(labels=lambda d: d["labels"].apply(json.dumps),
            labels_main=lambda d: d["labels_main"].apply(json.dumps))
    .to_csv(PATH_PROJECT+"/train.csv", index=True,index_label="image_id"))

# %%
dataset_df
# Out:
#                       imgHeight  imgWidth  \
# index
# weimar_000012_000019       1024      2048
# weimar_000052_000019       1024      2048
# weimar_000044_000019       1024      2048
# weimar_000009_000019       1024      2048
# weimar_000040_000019       1024      2048
# ...                         ...       ...
# bremen_000080_000019       1024      2048
# bremen_000076_000019       1024      2048
# bremen_000062_000019       1024      2048
# bremen_000077_000019       1024      2048
# bremen_000059_000019       1024      2048
#
#                                                                  labels  \
# index
# weimar_000012_000019  [road, sidewalk, sidewalk, vegetation, sky, fe...
# weimar_000052_000019  [sky, road, sidewalk, sidewalk, building, buil...
# weimar_000044_000019  [sky, road, building, vegetation, static, side...
# weimar_000009_000019  [road, sky, sidewalk, sidewalk, building, vege...
# weimar_000040_000019  [sky, road, vegetation, building, pole, static...
# ...                                                                 ...
# bremen_000080_000019  [sky, road, static, static, static, static, st...
# bremen_000076_000019  [sky, sidewalk, road, building, sidewalk, buil...
# bremen_000062_000019  [static, road, ground, pole, parking, car, per...
# bremen_000077_000019  [sky, road, vegetation, building, vegetation, ...
# bremen_000059_000019  [sky, road, vegetation, sidewalk, building, po...
#
#                       labels_count  \
# index
# weimar_000012_000019            69
# weimar_000052_000019            43
# weimar_000044_000019            43
# weimar_000009_000019            47
# weimar_000040_000019            48
# ...                            ...
# bremen_000080_000019            85
# bremen_000076_000019            76
# bremen_000062_000019            52
# bremen_000077_000019            89
# bremen_000059_000019            63
#
#                                                             labels_main  \
# index
# weimar_000012_000019  [flat, flat, flat, nature, sky, construction, ...
# weimar_000052_000019  [sky, flat, flat, flat, construction, construc...
# weimar_000044_000019  [sky, flat, construction, nature, void, flat, ...
# weimar_000009_000019  [flat, sky, flat, flat, construction, nature, ...
# weimar_000040_000019  [sky, flat, nature, construction, object, void...
# ...                                                                 ...
# bremen_000080_000019  [sky, flat, void, void, void, void, void, natu...
# bremen_000076_000019  [sky, flat, flat, construction, flat, construc...
# bremen_000062_000019  [void, flat, void, object, flat, vehicle, huma...
# bremen_000077_000019  [sky, flat, nature, construction, nature, void...
# bremen_000059_000019  [sky, flat, nature, flat, construction, object...
#
#                       labels_main_count    city
# index
# weimar_000012_000019                 69  weimar
# weimar_000052_000019                 43  weimar
# weimar_000044_000019                 42  weimar
# weimar_000009_000019                 46  weimar
# weimar_000040_000019                 47  weimar
# ...                                 ...     ...
# bremen_000080_000019                 84  bremen
# bremen_000076_000019                 74  bremen
# bremen_000062_000019                 51  bremen
# bremen_000077_000019                 87  bremen
# bremen_000059_000019                 63  bremen
#
# [2976 rows x 7 columns]

# %% [markdown]
# ## 2. Remapping Cityscapes → 8 classes

# %%
import numpy as np
import cv2
# ------------------------------------------------------------------
# Groupes d'IDs Cityscapes (id dans les *_gtFine_labelIds.png)
# regroupés par grande catégorie (8 classes)
# ------------------------------------------------------------------
void = [
    0,  # unlabeled
    1,  # ego vehicle
    2,  # rectification border
    3,  # out of roi
    4,  # static
    5,  # dynamic
    6,  # ground
]

flat = [
    7,  # road
    8,  # sidewalk
    9,  # parking
    10, # rail track
]

construction = [
    11, # building
    12, # wall
    13, # fence
    14, # guard rail
    15, # bridge
    16, # tunnel
]

object = [
    17, # pole
    18, # polegroup
    19, # traffic light
    20, # traffic sign
]

nature = [
    21, # vegetation
    22, # terrain
]

sky = [
    23, # sky
]

human = [
    24, # person
    25, # rider
]

vehicle = [
    26, # car
    27, # truck
    28, # bus
    29, # caravan
    30, # trailer
    31, # train
    32, # motorcycle
    33, # bicycle
    # id = -1 (license plate) n'est pas inclus
]

# ------------------------------------------------------------------
# REMAPPING vers 8 classes :
# 0: void, 1: flat, 2: construction, 3: object,
# 4: nature, 5: sky, 6: human, 7: vehicle
# ------------------------------------------------------------------
REMAPPING = {
    0: void,
    1: flat,
    2: construction,
    3: object,
    4: nature,
    5: sky,
    6: human,
    7: vehicle,
}

# LUT 256 -> 8 classes
lut = np.zeros(256, dtype=np.uint8)
for new_id, src_ids in REMAPPING.items():
    for sid in src_ids:
        lut[sid] = new_id

PALETTE = np.array([
    [  0,   0,   0],   # 0 void
    [128,  64, 128],   # 1 flat        (road)
    [ 70,  70,  70],   # 2 construction (building)
    [220, 220,   0],   # 3 object      (traffic sign style)
    [107, 142,  35],   # 4 nature      (vegetation)
    [ 70, 130, 180],   # 5 sky
    [220,  20,  60],   # 6 human       (person)
    [  0,   0, 142],   # 7 vehicle     (car)
], dtype=np.uint8)

# Noms des 8 classes dans l’ordre de ton mapping
LABELS = [
    "void",
    "flat",
    "construction",
    "object",
    "nature",
    "sky",
    "human",
    "vehicle",
]

# Dossier de sortie pour les fichiers de mapping
OUT_DIR = Path("mappings")  # ou Path(PATH_PROJECT) / "mappings" si tu préfères
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Sauvegarde des métadonnées de classes
with open(OUT_DIR / "labels.json", "w") as f:
    json.dump({"labels": LABELS}, f, indent=2, ensure_ascii=False)

# Sauvegarde de la LUT (256 -> 8) et de la palette (8 x 3)
np.save(OUT_DIR / "lut_256_to_8.npy", lut)
np.save(OUT_DIR / "palette_8x3.npy", PALETTE)

print("Mapping & palette sauvegardés dans", OUT_DIR)
# Out:
# Mapping & palette sauvegardés dans mappings

# %% [markdown]
# ## 3. Indexation des fichiers & correspondance image/mask

# %%
def gather_pairs(images_root, masks_root):
    """
    Associe:
      .../leftImg8bit/<split>/<city>/<frame>_leftImg8bit.png
    avec:
      .../gtFine/<split>/<city>/<frame>_gtFine_labelIds.png
    """
    images_root = Path(images_root)
    masks_root  = Path(masks_root)
    img_paths, mask_paths = [], []

    # parcourt toutes les images *_leftImg8bit.png (toutes villes)
    for img_path in images_root.rglob("*_leftImg8bit.png"):
        if not img_path.is_file():
            continue
        city = img_path.parent.name  # dossier ville
        base = img_path.name[:-len("_leftImg8bit.png")]  # <frame>
        mask_path = masks_root / city / f"{base}_gtFine_labelIds.png"
        if mask_path.exists():
            img_paths.append(str(img_path))
            mask_paths.append(str(mask_path))
        else:
            # fallback (au cas où)
            cand = list((masks_root / city).glob(f"{base}_gtFine_labelIds.png"))
            if cand:
                img_paths.append(str(img_path))
                mask_paths.append(str(cand[0]))

    return img_paths, mask_paths


train_imgs, train_msks = gather_pairs(FOLDER_TRAINING_IMAGES, FOLDER_TRAINING_MASK)
val_imgs,   val_msks   = gather_pairs(FOLDER_VALIDATION_IMAGES, FOLDER_VALIDATION_MASK)
test_imgs,  test_msks  = gather_pairs(FOLDER_TEST_IMAGES,      FOLDER_TEST_MASK)

print("Train pairs:", len(train_imgs))
print("Val   pairs:", len(val_imgs))
print("Test  pairs:", len(test_imgs))

with open(OUT_DIR / "index_train.json", "w") as f:
    json.dump({"images": train_imgs, "masks": train_msks}, f, indent=2)
with open(OUT_DIR / "index_val.json", "w") as f:
    json.dump({"images": val_imgs, "masks": val_msks}, f, indent=2)
with open(OUT_DIR / "index_test.json", "w") as f:
    json.dump({"images": test_imgs, "masks": test_msks}, f, indent=2)
# Out:
# Train pairs: 2975
# Val   pairs: 500
# Test  pairs: 1525

# %% [markdown]
# ## 4. Pipeline tf.data (+ augmentations)

# %%
AUTOTUNE = tf.data.AUTOTUNE
lut_tf = tf.constant(np.load(str(OUT_DIR / "lut_256_to_8.npy")), dtype=tf.uint8)

def _load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img

def _load_mask(mask_path):
    m = tf.io.read_file(mask_path)
    m = tf.image.decode_png(m, channels=1)
    m = tf.squeeze(m, axis=-1)
    m = tf.gather(lut_tf, tf.cast(m, tf.int32))
    m = tf.expand_dims(m, axis=-1)
    return m

def _resize(img, msk):
    img = tf.image.resize(img, (IMG_HEIGHT, IMG_WIDTH), method="bilinear")
    msk = tf.image.resize(msk, (IMG_HEIGHT, IMG_WIDTH), method="nearest")
    return img, msk

def _augment(img, msk):
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        msk = tf.image.flip_left_right(msk)
    img = tf.image.random_brightness(img, max_delta=0.05)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, msk

def _prep_train(img_path, msk_path):
    img = _load_image(img_path)
    msk = _load_mask(msk_path)
    img, msk = _resize(img, msk)
    img, msk = _augment(img, msk)
    return img, tf.cast(msk, tf.int32)

def _prep_eval(img_path, msk_path):
    img = _load_image(img_path)
    msk = _load_mask(msk_path)
    img, msk = _resize(img, msk)
    return img, tf.cast(msk, tf.int32)

def make_ds(imgs, msks, training=True, batch_size=BATCH_SIZE):
    # forcer le type string propre
    imgs = [str(p) for p in imgs]
    msks = [str(p) for p in msks]

    imgs = tf.constant(imgs, dtype=tf.string)
    msks = tf.constant(msks, dtype=tf.string)

    ds = tf.data.Dataset.from_tensor_slices((imgs, msks))
    if training:
        buf = int(min(1000, imgs.shape[0]))
        if buf > 0:
            ds = ds.shuffle(buf, seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(_prep_train if training else _prep_eval, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds

train_ds = make_ds(train_imgs, train_msks, training=True)
val_ds   = make_ds(val_imgs,   val_msks,   training=False)
test_ds  = make_ds(test_imgs,  test_msks,  training=False)

for batch in train_ds.take(1):
    print("Batch images:", batch[0].shape, "Batch masks:", batch[1].shape)
# Out:
# Batch images: (4, 512, 1024, 3) Batch masks: (4, 512, 1024, 1)

# %% [markdown]
# ## 5. Pertes & métriques (mIoU callback)

# %%
from tensorflow.keras import backend as K

CE_LOSS = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

class MeanIoUCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_dataset, name="val_mIoU"):
        super().__init__()
        self.val_dataset = val_dataset
        self.name = name

    def on_epoch_end(self, epoch, logs=None):
        miou = tf.keras.metrics.MeanIoU(num_classes=N_CLASSES)
        for x, y in self.val_dataset:
            pred = self.model.predict(x, verbose=0)
            pred_labels = tf.argmax(pred, axis=-1)
            pred_labels = tf.expand_dims(pred_labels, axis=-1)
            miou.update_state(y, pred_labels)
        logs = logs or {}
        logs[self.name] = miou.result().numpy()
        self.model.history.history.setdefault(self.name, []).append(logs[self.name])
        print(f" — {self.name}: {logs[self.name]:.4f}")

# %% [markdown]
# ## 6. Modèles : U-Net et U-Net-MobileNetV2

# %%
from tensorflow.keras import layers, models

def conv_block(x, filters, k=3):
    x = layers.Conv2D(filters, k, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, k, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def encoder_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPooling2D((2,2))(c)
    return c, p

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, (2,2), strides=(2,2), padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

def build_unet(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=N_CLASSES, base_filters=64):
    inputs = layers.Input(shape=input_shape)
    c1, p1 = encoder_block(inputs, base_filters)
    c2, p2 = encoder_block(p1, base_filters*2)
    c3, p3 = encoder_block(p2, base_filters*4)
    c4, p4 = encoder_block(p3, base_filters*8)

    bn = conv_block(p4, base_filters*16)

    d1 = decoder_block(bn, c4, base_filters*8)
    d2 = decoder_block(d1, c3, base_filters*4)
    d3 = decoder_block(d2, c2, base_filters*2)
    d4 = decoder_block(d3, c1, base_filters)

    outputs = layers.Conv2D(num_classes, 1, activation="softmax")(d4)
    return models.Model(inputs, outputs, name="UNet")

def build_unet_mobilenetv2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=N_CLASSES):
    base = tf.keras.applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights="imagenet"
    )

    # Couches de skip-connection
    skips = [
        base.get_layer("block_1_expand_relu").output,   # ~ 1/2
        base.get_layer("block_3_expand_relu").output,   # ~ 1/4
        base.get_layer("block_6_expand_relu").output,   # ~ 1/8
        base.get_layer("block_13_expand_relu").output,  # ~ 1/16
    ]
    encoder_output = base.get_layer("block_16_project").output  # ~ 1/32

    x = encoder_output

    # Decoder : 1/32 → 1/16 → 1/8 → 1/4 → 1/2
    filters = [256, 128, 64, 32]
    for i, f in enumerate(filters):
        x = layers.Conv2DTranspose(f, 3, strides=2, padding="same")(x)
        x = layers.Concatenate()([x, skips[-(i+1)]])
        x = layers.Conv2D(f, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(f, 3, padding="same", activation="relu")(x)

    # Dernier upsampling 1/2 → 1 (512 x 1024)
    x = layers.Conv2DTranspose(16, 3, strides=2, padding="same")(x)
    x = layers.Conv2D(16, 3, padding="same", activation="relu")(x)

    outputs = layers.Conv2D(num_classes, 1, activation="softmax")(x)
    model = models.Model(inputs=base.input, outputs=outputs, name="UNet_MobileNetV2")
    return model

unet = build_unet()
unet_mb = build_unet_mobilenetv2()
unet.summary()
unet_mb.summary()

config = {
    "img_height": IMG_HEIGHT,
    "img_width": IMG_WIDTH,
    "n_classes": N_CLASSES,
    "labels": LABELS,
    "preprocess": "rescale_0_1",
    "color_palette": "palette_8x3.npy"
}
with open(OUT_DIR / "inference_config.json", "w") as f:
    json.dump(config, f, indent=2, ensure_ascii=False)
print("Config d'inférence sauvegardée.")
# Out:
# /tmp/ipython-input-1551138032.py:41: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = tf.keras.applications.MobileNetV2(
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 512, 1024, │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 512, 1024, │      1,792 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 1024, │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 512, 1024, │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 512, 1024, │     36,928 │ re_lu_18[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 1024, │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 512, 1024, │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 256, 512,  │          0 │ re_lu_19[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 512,  │     73,856 │ max_pooling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 512,  │        512 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 256, 512,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 512,  │    147,584 │ re_lu_20[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 512,  │        512 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 256, 512,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 128, 256,  │          0 │ re_lu_21[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 256,  │    295,168 │ max_pooling2d_5[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256,  │      1,024 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 128, 256,  │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 256,  │    590,080 │ re_lu_22[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256,  │      1,024 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 128, 256,  │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 64, 128,   │          0 │ re_lu_23[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 128,   │  1,180,160 │ max_pooling2d_6[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128,   │      2,048 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 64, 128,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 128,   │  2,359,808 │ re_lu_24[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128,   │      2,048 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 64, 128,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 32, 64,    │          0 │ re_lu_25[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 64,    │  4,719,616 │ max_pooling2d_7[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64,    │      4,096 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 32, 64,    │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 64,    │  9,438,208 │ re_lu_26[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 64,    │      4,096 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 32, 64,    │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 128,   │  2,097,664 │ re_lu_27[0][0]    │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 64, 128,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ re_lu_25[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 64, 128,   │  4,719,104 │ concatenate_8[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128,   │      2,048 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 64, 128,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 128,   │  2,359,808 │ re_lu_28[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128,   │      2,048 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 64, 128,   │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 128, 256,  │    524,544 │ re_lu_29[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 128, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 128, 256,  │  1,179,904 │ concatenate_9[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256,  │      1,024 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 128, 256,  │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 256,  │    590,080 │ re_lu_30[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256,  │      1,024 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 128, 256,  │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 256, 512,  │    131,200 │ re_lu_31[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 256, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 512,  │    295,040 │ concatenate_10[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 512,  │        512 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 256, 512,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 512,  │    147,584 │ re_lu_32[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 512,  │        512 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 256, 512,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 512, 1024, │     32,832 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 512, 1024, │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 512, 1024, │     73,792 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 1024, │        256 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 512, 1024, │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 512, 1024, │     36,928 │ re_lu_34[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 1024, │        256 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 512, 1024, │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 512, 1024, │        520 │ re_lu_35[0][0]    │
# │                     │ 8)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,752 (118.47 MB)
#  Trainable params: 31,043,976 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)
# Model: "UNet_MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 512, 1024, │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 256, 512,  │        864 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 256, 512,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 256, 512,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 512,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 512,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 512,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 256, 512,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 256, 512,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 256, 512,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 256, 512,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 256, 512,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 257, 513,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 128, 256,  │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 128, 256,  │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 128, 256,  │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 128, 256,  │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 128, 256,  │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 128, 256,  │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 128, 256,  │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 128, 256,  │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 128, 256,  │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 128, 256,  │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 128, 256,  │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 128, 256,  │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 128, 256,  │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 128, 256,  │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 128, 256,  │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 128, 256,  │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 128, 256,  │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 129, 257,  │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 64, 128,   │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 64, 128,   │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 64, 128,   │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 64, 128,   │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 64, 128,   │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 64, 128,   │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 64, 128,   │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 64, 128,   │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 64, 128,   │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 64, 128,   │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 64, 128,   │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 64, 128,   │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 64, 128,   │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 64, 128,   │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 64, 128,   │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 64, 128,   │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 64, 128,   │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 64, 128,   │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 64, 128,   │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 64, 128,   │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 64, 128,   │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 64, 128,   │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 64, 128,   │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 64, 128,   │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 64, 128,   │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 64, 128,   │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 65, 129,   │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 32, 64,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 32, 64,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 32, 64,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 32, 64,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 32, 64,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 32, 64,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 32, 64,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 32, 64,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 32, 64,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 32, 64,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 32, 64,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 32, 64,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 32, 64,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 32, 64,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 32, 64,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 32, 64,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 32, 64,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 32, 64,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 32, 64,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 32, 64,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 32, 64,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 32, 64,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 32, 64,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 32, 64,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 32, 64,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 32, 64,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 32, 64,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 32, 64,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 32, 64,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 32, 64,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 32, 64,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 32, 64,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 32, 64,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 32, 64,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 32, 64,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 32, 64,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 32, 64,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 32, 64,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 32, 64,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 32, 64,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 32, 64,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 32, 64,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 32, 64,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 32, 64,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 32, 64,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 32, 64,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 32, 64,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 32, 64,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 32, 64,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 32, 64,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 32, 64,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 32, 64,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 32, 64,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 32, 64,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 32, 64,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 32, 64,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 32, 64,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 32, 64,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 32, 64,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 32, 64,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 32, 64,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 33, 65,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 16, 32,    │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 16, 32,    │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 16, 32,    │          0 │ block_13_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 16, 32,    │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 16, 32,    │        640 │ block_13_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 16, 32,    │    153,600 │ block_13_project… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 16, 32,    │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 16, 32,    │          0 │ block_14_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 16, 32,    │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 16, 32,    │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 16, 32,    │          0 │ block_14_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 16, 32,    │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 16, 32,    │        640 │ block_14_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 16, 32,    │          0 │ block_13_project… │
# │                     │ 160)              │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 16, 32,    │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 16, 32,    │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 16, 32,    │          0 │ block_15_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 16, 32,    │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 16, 32,    │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 16, 32,    │          0 │ block_15_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 16, 32,    │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 16, 32,    │        640 │ block_15_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 16, 32,    │          0 │ block_14_add[0][… │
# │                     │ 160)              │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 16, 32,    │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 16, 32,    │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 16, 32,    │          0 │ block_16_expand_… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 16, 32,    │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 16, 32,    │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 16, 32,    │          0 │ block_16_depthwi… │
# │ (ReLU)              │ 960)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 16, 32,    │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_12 │ (None, 32, 64,    │    737,536 │ block_16_project… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 32, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 832)              │            │ block_13_expand_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 64,    │  1,917,184 │ concatenate_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 64,    │    590,080 │ conv2d_47[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 64, 128,   │    295,040 │ conv2d_48[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 64, 128,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 320)              │            │ block_6_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 64, 128,   │    368,768 │ concatenate_13[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 128,   │    147,584 │ conv2d_49[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 128, 256,  │     73,792 │ conv2d_50[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 128, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 208)              │            │ block_3_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 256,  │    119,872 │ concatenate_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 128, 256,  │     36,928 │ conv2d_51[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 256, 512,  │     18,464 │ conv2d_52[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 256, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ block_1_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 256, 512,  │     36,896 │ concatenate_15[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 512,  │      9,248 │ conv2d_53[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 512, 1024, │      4,624 │ conv2d_54[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 512, 1024, │      2,320 │ conv2d_transpose… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 512, 1024, │        136 │ conv2d_55[0][0]   │
# │                     │ 8)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,200,456 (23.65 MB)
#  Trainable params: 6,169,544 (23.53 MB)
#  Non-trainable params: 30,912 (120.75 KB)
# Config d'inférence sauvegardée.

# %% [markdown]
# ## 7. Entraînement & suivi mIoU

# %%
def compile_model(model, lr=1e-3):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=opt,
                  loss=CE_LOSS,
                  metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name="acc")])
    return model

callbacks_common = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2),
    tf.keras.callbacks.CSVLogger(str(OUT_DIR / "training_log.csv"), append=True)
]
print("Train Unet...")
unet = compile_model(unet, lr=1e-3)
miou_cb_unet = MeanIoUCallback(val_ds, name="val_mIoU")
ckpt_unet = tf.keras.callbacks.ModelCheckpoint(
    filepath=str(OUT_DIR / "best_unet.keras"),
    monitor="val_loss",
    save_best_only=True
)
history_unet = unet.fit(
    train_ds, validation_data=val_ds,
    epochs=EPOCHS, callbacks=callbacks_common + [miou_cb_unet, ckpt_unet],
    verbose=1
)

print("Train Unet-MobileNetV2...")
unet_mb = compile_model(unet_mb, lr=1e-3)
miou_cb_unetmb = MeanIoUCallback(val_ds, name="val_mIoU")
ckpt_unetmb = tf.keras.callbacks.ModelCheckpoint(
    filepath=str(OUT_DIR / "best_unet_mobilenetv2.keras"),
    monitor="val_loss",
    save_best_only=True
)
history_unet_mb = unet_mb.fit(
    train_ds, validation_data=val_ds,
    epochs=EPOCHS, callbacks=callbacks_common + [miou_cb_unetmb, ckpt_unetmb],
    verbose=1
)

import pandas as pd
pd.DataFrame(history_unet.history).to_csv(OUT_DIR / "history_unet.csv", index=False)
pd.DataFrame(history_unet_mb.history).to_csv(OUT_DIR / "history_unet_mobilenetv2.csv", index=False)
print("Historiques sauvegardés.")
# Out:
# Epoch 1/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - acc: 0.6969 - loss: 0.9086 — val_mIoU: 0.3640
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 643s 760ms/step - acc: 0.6970 - loss: 0.9083 - val_acc: 0.7368 - val_loss: 1.0759 - learning_rate: 0.0010 - val_mIoU: 0.3640
# Epoch 2/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.8391 - loss: 0.5063 — val_mIoU: 0.4937
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 229ms/step - acc: 0.8391 - loss: 0.5062 - val_acc: 0.8030 - val_loss: 0.6403 - learning_rate: 0.0010 - val_mIoU: 0.4937
# Epoch 3/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.8664 - loss: 0.4263 — val_mIoU: 0.5673
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 230ms/step - acc: 0.8664 - loss: 0.4263 - val_acc: 0.8324 - val_loss: 0.5326 - learning_rate: 0.0010 - val_mIoU: 0.5673
# Epoch 4/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.8848 - loss: 0.3701 — val_mIoU: 0.6071
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 170s 228ms/step - acc: 0.8848 - loss: 0.3701 - val_acc: 0.8604 - val_loss: 0.4553 - learning_rate: 0.0010 - val_mIoU: 0.6071
# Epoch 5/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.8918 - loss: 0.3440 — val_mIoU: 0.6175
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.8918 - loss: 0.3440 - val_acc: 0.8676 - val_loss: 0.4295 - learning_rate: 0.0010 - val_mIoU: 0.6175
# Epoch 6/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9011 - loss: 0.3153 — val_mIoU: 0.6329
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 170s 228ms/step - acc: 0.9011 - loss: 0.3153 - val_acc: 0.8643 - val_loss: 0.4356 - learning_rate: 0.0010 - val_mIoU: 0.6329
# Epoch 7/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9028 - loss: 0.3093 — val_mIoU: 0.6740
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9028 - loss: 0.3093 - val_acc: 0.8848 - val_loss: 0.3745 - learning_rate: 0.0010 - val_mIoU: 0.6740
# Epoch 8/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9073 - loss: 0.2912 — val_mIoU: 0.6581
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 170s 229ms/step - acc: 0.9073 - loss: 0.2912 - val_acc: 0.8791 - val_loss: 0.4108 - learning_rate: 0.0010 - val_mIoU: 0.6581
# Epoch 9/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9138 - loss: 0.2716 — val_mIoU: 0.6941
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9138 - loss: 0.2716 - val_acc: 0.8906 - val_loss: 0.3420 - learning_rate: 0.0010 - val_mIoU: 0.6941
# Epoch 10/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9144 - loss: 0.2663 — val_mIoU: 0.6369
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 229ms/step - acc: 0.9144 - loss: 0.2663 - val_acc: 0.8644 - val_loss: 0.4236 - learning_rate: 0.0010 - val_mIoU: 0.6369
# Epoch 11/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9182 - loss: 0.2569 — val_mIoU: 0.6594
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 170s 228ms/step - acc: 0.9182 - loss: 0.2569 - val_acc: 0.8688 - val_loss: 0.4287 - learning_rate: 0.0010 - val_mIoU: 0.6594
# Epoch 12/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9240 - loss: 0.2355 — val_mIoU: 0.7450
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9240 - loss: 0.2355 - val_acc: 0.9098 - val_loss: 0.2899 - learning_rate: 5.0000e-04 - val_mIoU: 0.7450
# Epoch 13/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9269 - loss: 0.2239 — val_mIoU: 0.7278
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 229ms/step - acc: 0.9269 - loss: 0.2238 - val_acc: 0.9063 - val_loss: 0.2952 - learning_rate: 5.0000e-04 - val_mIoU: 0.7278
# Epoch 14/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9289 - loss: 0.2178 — val_mIoU: 0.7570
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9289 - loss: 0.2178 - val_acc: 0.9133 - val_loss: 0.2742 - learning_rate: 5.0000e-04 - val_mIoU: 0.7570
# Epoch 15/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9292 - loss: 0.2154 — val_mIoU: 0.7444
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 170s 229ms/step - acc: 0.9292 - loss: 0.2154 - val_acc: 0.9140 - val_loss: 0.2770 - learning_rate: 5.0000e-04 - val_mIoU: 0.7444
# Epoch 16/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9319 - loss: 0.2069 — val_mIoU: 0.7608
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 229ms/step - acc: 0.9319 - loss: 0.2069 - val_acc: 0.9163 - val_loss: 0.2956 - learning_rate: 5.0000e-04 - val_mIoU: 0.7608
# Epoch 17/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9333 - loss: 0.1982 — val_mIoU: 0.7778
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 173s 232ms/step - acc: 0.9333 - loss: 0.1982 - val_acc: 0.9205 - val_loss: 0.2587 - learning_rate: 2.5000e-04 - val_mIoU: 0.7778
# Epoch 18/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9365 - loss: 0.1906 — val_mIoU: 0.7784
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9365 - loss: 0.1906 - val_acc: 0.9210 - val_loss: 0.2634 - learning_rate: 2.5000e-04 - val_mIoU: 0.7784
# Epoch 19/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9374 - loss: 0.1883 — val_mIoU: 0.7727
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 173s 232ms/step - acc: 0.9374 - loss: 0.1883 - val_acc: 0.9206 - val_loss: 0.2540 - learning_rate: 2.5000e-04 - val_mIoU: 0.7727
# Epoch 20/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9387 - loss: 0.1852 — val_mIoU: 0.7768
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 173s 233ms/step - acc: 0.9387 - loss: 0.1852 - val_acc: 0.9211 - val_loss: 0.2501 - learning_rate: 2.5000e-04 - val_mIoU: 0.7768
# Epoch 21/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9385 - loss: 0.1825 — val_mIoU: 0.7777
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 172s 231ms/step - acc: 0.9385 - loss: 0.1825 - val_acc: 0.9201 - val_loss: 0.2502 - learning_rate: 2.5000e-04 - val_mIoU: 0.7777
# Epoch 22/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9394 - loss: 0.1823 — val_mIoU: 0.7574
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 230ms/step - acc: 0.9394 - loss: 0.1822 - val_acc: 0.9121 - val_loss: 0.2928 - learning_rate: 2.5000e-04 - val_mIoU: 0.7574
# Epoch 23/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9418 - loss: 0.1720 — val_mIoU: 0.7885
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 230ms/step - acc: 0.9418 - loss: 0.1719 - val_acc: 0.9244 - val_loss: 0.2511 - learning_rate: 1.2500e-04 - val_mIoU: 0.7885
# Epoch 24/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9427 - loss: 0.1678 — val_mIoU: 0.7810
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 230ms/step - acc: 0.9427 - loss: 0.1678 - val_acc: 0.9233 - val_loss: 0.2556 - learning_rate: 1.2500e-04 - val_mIoU: 0.7810
# Epoch 25/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - acc: 0.9454 - loss: 0.1599 — val_mIoU: 0.7875
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 171s 229ms/step - acc: 0.9454 - loss: 0.1599 - val_acc: 0.9244 - val_loss: 0.2546 - learning_rate: 6.2500e-05 - val_mIoU: 0.7875
# Epoch 1/25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3671712543.py in <cell line: 0>()
#      32     save_best_only=True
#      33 )
# ---> 34 history_unet_mb = unet_mb.fit(
#      35     train_ds, validation_data=val_ds,
#      36     epochs=EPOCHS, callbacks=callbacks_common + [miou_cb_unetmb, ckpt_unetmb],
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/nn.py in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     739     for e1, e2 in zip(target.shape, output.shape[:-1]):
#     740         if e1 is not None and e2 is not None and e1 != e2:
# --> 741             raise ValueError(
#     742                 "Arguments `target` and `output` must have the same shape "
#     743                 "up until the last dimension: "
#
# ValueError: Arguments `target` and `output` must have the same shape up until the last dimension: target.shape=(None, 512, 1024), output.shape=(None, 256, 512, 8)

# %%
# 2) Compiler SEULEMENT le modèle MobileNet UNet
unet_mb = compile_model(unet_mb, lr=1e-3)

miou_cb_unetmb = MeanIoUCallback(val_ds, name="val_mIoU")
ckpt_unetmb = tf.keras.callbacks.ModelCheckpoint(
    filepath=str(OUT_DIR / "best_unet_mobilenetv2.keras"),
    monitor="val_loss",
    save_best_only=True
)

# 3) Entraîner SEULEMENT unet_mb
history_unet_mb = unet_mb.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks_common + [miou_cb_unetmb, ckpt_unetmb],
    verbose=1
)
# Out:
# Epoch 1/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - acc: 0.7277 - loss: 0.8209 — val_mIoU: 0.1468
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 285s 240ms/step - acc: 0.7279 - loss: 0.8205 - val_acc: 0.3323 - val_loss: 2.1684 - learning_rate: 0.0010 - val_mIoU: 0.1468
# Epoch 2/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 0.8997 - loss: 0.3447 — val_mIoU: 0.2813
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 117ms/step - acc: 0.8997 - loss: 0.3447 - val_acc: 0.4119 - val_loss: 2.5521 - learning_rate: 0.0010 - val_mIoU: 0.2813
# Epoch 3/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.9132 - loss: 0.2925 — val_mIoU: 0.0632
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.9131 - loss: 0.2928 - val_acc: 0.1326 - val_loss: 4.6108 - learning_rate: 0.0010 - val_mIoU: 0.0632
# Epoch 4/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.7746 - loss: 0.6940 — val_mIoU: 0.1458
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.7747 - loss: 0.6938 - val_acc: 0.3756 - val_loss: 2.1301 - learning_rate: 5.0000e-04 - val_mIoU: 0.1458
# Epoch 5/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8292 - loss: 0.5484 — val_mIoU: 0.1931
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 117ms/step - acc: 0.8292 - loss: 0.5484 - val_acc: 0.4547 - val_loss: 2.2058 - learning_rate: 5.0000e-04 - val_mIoU: 0.1931
# Epoch 6/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8430 - loss: 0.5005 — val_mIoU: 0.2856
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8430 - loss: 0.5004 - val_acc: 0.5645 - val_loss: 1.5064 - learning_rate: 5.0000e-04 - val_mIoU: 0.2856
# Epoch 7/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8523 - loss: 0.4724 — val_mIoU: 0.3785
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 119ms/step - acc: 0.8523 - loss: 0.4724 - val_acc: 0.6448 - val_loss: 1.1639 - learning_rate: 5.0000e-04 - val_mIoU: 0.3785
# Epoch 8/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8517 - loss: 0.4743 — val_mIoU: 0.4778
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8517 - loss: 0.4742 - val_acc: 0.7670 - val_loss: 0.6947 - learning_rate: 5.0000e-04 - val_mIoU: 0.4778
# Epoch 9/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8606 - loss: 0.4447 — val_mIoU: 0.4664
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8606 - loss: 0.4447 - val_acc: 0.7461 - val_loss: 0.7671 - learning_rate: 5.0000e-04 - val_mIoU: 0.4664
# Epoch 10/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8644 - loss: 0.4330 — val_mIoU: 0.5511
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8644 - loss: 0.4330 - val_acc: 0.8405 - val_loss: 0.5012 - learning_rate: 5.0000e-04 - val_mIoU: 0.5511
# Epoch 11/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8680 - loss: 0.4219 — val_mIoU: 0.5236
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8680 - loss: 0.4219 - val_acc: 0.7735 - val_loss: 0.7173 - learning_rate: 5.0000e-04 - val_mIoU: 0.5236
# Epoch 12/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8701 - loss: 0.4136 — val_mIoU: 0.5378
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8701 - loss: 0.4136 - val_acc: 0.8094 - val_loss: 0.5999 - learning_rate: 5.0000e-04 - val_mIoU: 0.5378
# Epoch 13/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8757 - loss: 0.3950 — val_mIoU: 0.5774
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8757 - loss: 0.3950 - val_acc: 0.8337 - val_loss: 0.5182 - learning_rate: 2.5000e-04 - val_mIoU: 0.5774
# Epoch 14/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8794 - loss: 0.3849 — val_mIoU: 0.5972
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8794 - loss: 0.3849 - val_acc: 0.8475 - val_loss: 0.4775 - learning_rate: 2.5000e-04 - val_mIoU: 0.5972
# Epoch 15/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8756 - loss: 0.3947 — val_mIoU: 0.5994
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 90s 120ms/step - acc: 0.8756 - loss: 0.3946 - val_acc: 0.8534 - val_loss: 0.4627 - learning_rate: 2.5000e-04 - val_mIoU: 0.5994
# Epoch 16/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8810 - loss: 0.3788 — val_mIoU: 0.6003
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8810 - loss: 0.3788 - val_acc: 0.8590 - val_loss: 0.4427 - learning_rate: 2.5000e-04 - val_mIoU: 0.6003
# Epoch 17/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8817 - loss: 0.3771 — val_mIoU: 0.6133
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8817 - loss: 0.3771 - val_acc: 0.8548 - val_loss: 0.4491 - learning_rate: 2.5000e-04 - val_mIoU: 0.6133
# Epoch 18/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8816 - loss: 0.3754 — val_mIoU: 0.6123
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8816 - loss: 0.3754 - val_acc: 0.8516 - val_loss: 0.4575 - learning_rate: 2.5000e-04 - val_mIoU: 0.6123
# Epoch 19/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8841 - loss: 0.3689 — val_mIoU: 0.6248
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8841 - loss: 0.3689 - val_acc: 0.8613 - val_loss: 0.4353 - learning_rate: 1.2500e-04 - val_mIoU: 0.6248
# Epoch 20/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8845 - loss: 0.3661 — val_mIoU: 0.6319
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 89s 119ms/step - acc: 0.8845 - loss: 0.3661 - val_acc: 0.8678 - val_loss: 0.4153 - learning_rate: 1.2500e-04 - val_mIoU: 0.6319
# Epoch 21/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8860 - loss: 0.3621 — val_mIoU: 0.6351
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8860 - loss: 0.3621 - val_acc: 0.8690 - val_loss: 0.4084 - learning_rate: 1.2500e-04 - val_mIoU: 0.6351
# Epoch 22/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8852 - loss: 0.3631 — val_mIoU: 0.6278
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8852 - loss: 0.3631 - val_acc: 0.8663 - val_loss: 0.4197 - learning_rate: 1.2500e-04 - val_mIoU: 0.6278
# Epoch 23/25
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8852 - loss: 0.3631 — val_mIoU: 0.6408
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8852 - loss: 0.3631 - val_acc: 0.8689 - val_loss: 0.4108 - learning_rate: 1.2500e-04 - val_mIoU: 0.6408
# Epoch 24/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8872 - loss: 0.3565 — val_mIoU: 0.6391
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 88s 118ms/step - acc: 0.8872 - loss: 0.3565 - val_acc: 0.8707 - val_loss: 0.4054 - learning_rate: 6.2500e-05 - val_mIoU: 0.6391
# Epoch 25/25
# 743/744 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.8882 - loss: 0.3535 — val_mIoU: 0.6286
# 744/744 ━━━━━━━━━━━━━━━━━━━━ 87s 117ms/step - acc: 0.8882 - loss: 0.3535 - val_acc: 0.8650 - val_loss: 0.4208 - learning_rate: 6.2500e-05 - val_mIoU: 0.6286

# %% [markdown]
# ## 8. Sélection du meilleur modèle & export

# %%
import pandas as pd

def best_miou(csv_path, key="val_mIoU"):
    p = Path(csv_path)
    if not p.exists():
        return -1.0
    df = pd.read_csv(p)
    return float(df[key].max()) if key in df.columns else -1.0

miou_unet = best_miou(OUT_DIR / "history_unet.csv")
miou_unet_mb = best_miou(OUT_DIR / "history_unet_mobilenetv2.csv")

print("Best val mIoU — UNet:", miou_unet)
print("Best val mIoU — UNet-MobileNetV2:", miou_unet_mb)

if miou_unet_mb > miou_unet:
    best_name = "unet_mobilenetv2"
    best_ckpt = OUT_DIR / "best_unet_mobilenetv2.keras"
    model = tf.keras.models.load_model(best_ckpt, compile=False)
else:
    best_name = "unet"
    best_ckpt = OUT_DIR / "best_unet.keras"
    model = tf.keras.models.load_model(best_ckpt, compile=False)

BEST_EXPORT_DIR = OUT_DIR / f"savedmodel_{best_name}"
tf.keras.models.save_model(model, BEST_EXPORT_DIR, include_optimizer=False, save_format="tf")
print("Export:", BEST_EXPORT_DIR)

with open(OUT_DIR / "best_model.json", "w") as f:
    json.dump({
        "best_model": best_name,
        "checkpoint": str(best_ckpt),
        "export_dir": str(BEST_EXPORT_DIR),
        "val_mIoU_unet": miou_unet,
        "val_mIoU_unet_mobilenetv2": miou_unet_mb
    }, f, indent=2)

# %% [markdown]
# ## 9. Évaluation test

# %%
with open(OUT_DIR / "best_model.json") as f:
    meta = json.load(f)
best_dir = meta["export_dir"]
best_model = tf.keras.models.load_model(best_dir, compile=False)

miou_test = tf.keras.metrics.MeanIoU(num_classes=N_CLASSES)
acc_test = tf.keras.metrics.SparseCategoricalAccuracy()

for x, y in test_ds:
    pred = best_model.predict(x, verbose=0)
    acc_test.update_state(y, pred)
    pred_labels = tf.argmax(pred, axis=-1)
    pred_labels = tf.expand_dims(pred_labels, axis=-1)
    miou_test.update_state(y, pred_labels)

print("Test mIoU:", miou_test.result().numpy())
print("Test Accuracy:", acc_test.result().numpy())

with open(OUT_DIR / "metrics_test.json", "w") as f:
    json.dump({
        "test_mIoU": float(miou_test.result().numpy()),
        "test_acc": float(acc_test.result().numpy())
    }, f, indent=2)
print("Métriques test sauvegardées.")

# %% [markdown]
# ## 10. Prédiction & visualisation

# %%
import matplotlib.pyplot as plt

palette = np.load(str(OUT_DIR / "palette_8x3.npy"))

def colorize_mask(mask_np):
    colored = palette[mask_np]
    return colored.astype(np.uint8)

def predict_image(img_path, model, save_dir=OUT_DIR/"predictions"):
    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    img_raw = tf.io.read_file(img_path)
    img = tf.image.decode_png(img_raw, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img_resized = tf.image.resize(img, (IMG_HEIGHT, IMG_WIDTH))
    pred = model.predict(tf.expand_dims(img_resized, 0), verbose=0)[0]
    pred_lbl = tf.argmax(pred, axis=-1).numpy().astype(np.uint8)
    color = colorize_mask(pred_lbl)

    stem = Path(img_path).stem.replace("_leftImg8bit", "")
    out_mask = save_dir / f"{stem}_pred_mask.png"
    out_visu = save_dir / f"{stem}_visu.png"

    tf.keras.utils.save_img(str(out_mask), np.expand_dims(pred_lbl, -1), scale=False)
    tf.keras.utils.save_img(str(out_visu), color, scale=False)

    plt.figure(figsize=(16,6))
    plt.subplot(1,3,1); plt.title("Image"); plt.imshow(img_resized.numpy()); plt.axis("off")
    plt.subplot(1,3,2); plt.title("Mask (labels)"); plt.imshow(pred_lbl, vmin=0, vmax=N_CLASSES-1); plt.axis("off")
    plt.subplot(1,3,3); plt.title("Mask colorisé"); plt.imshow(color); plt.axis("off")
    plt.show()

if len(test_imgs) > 0:
    predict_image(test_imgs[0], best_model)
else:
    print("Pas d'images test indexées.")

# %% [markdown]
# ## 11. Exports pour l'API

# %%
print("Contenu de", OUT_DIR)
for p in sorted(OUT_DIR.iterdir()):
    print(" -", p.name)
